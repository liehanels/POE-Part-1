# %%
# Preparing the environment and loading the dataset
# Install dependencies
# %pip install -r ../requirements.txt

# Import necessary libraries
import numpy as np
import pandas as pd
import tensorflow as tf
import os

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Defines the path to the data directory
data_path = "c:/Users/owner/OneDrive/Varsity/2025/PGDDA/S2/PDAN/Projects/POE-Part-1/data"

# Create the directory if it doesn't exist
os.makedirs(data_path, exist_ok=True)

# Construct the full file path using os.path.join (recommended for cross-platform compatibility by Python documentation)
file_path = os.path.join(data_path, "train.csv")

# Load dataset
try:
    data = pd.read_csv(file_path)
    # Display the first few rows
    print("Dataset loaded successfully!")
    print(data.head())
    # A nifty recommendation if the file is not found
except FileNotFoundError:
    print(f"Error: The file was not found at {file_path}")
    print("Please check the following:")
    print("1. Ensure the 'kaggle' command ran successfully and downloaded the files.")
    print("2. Check the data directory for the actual filenames. It should contain 'lda_features.csv'.")
# Out:
# Requirement already satisfied: numpy in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from -r ../requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: pandas in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from -r ../requirements.txt (line 2)) (2.3.2)
# Requirement already satisfied: tensorflow in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from -r ../requirements.txt (line 3)) (2.20.0)
# Requirement already satisfied: matplotlib in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from -r ../requirements.txt (line 4)) (3.10.6)
# Requirement already satisfied: seaborn in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from -r ../requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from -r ../requirements.txt (line 6)) (1.7.2)
# Requirement already satisfied: scikit-fuzzy in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from -r ../requirements.txt (line 7)) (0.5.0)
# Requirement already satisfied: kaggle in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from -r ../requirements.txt (line 8)) (1.7.4.5)
# Requirement already satisfied: networkx in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from -r ../requirements.txt (line 9)) (3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from pandas->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from pandas->-r ../requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from pandas->-r ../requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (3.4.0)
# Requirement already satisfied: packaging in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (6.32.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (1.75.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (3.11.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorflow->-r ../requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 3)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 3)) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow->-r ../requirements.txt (line 3)) (3.9)
# Requirement already satisfied: pillow in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow->-r ../requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow->-r ../requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow->-r ../requirements.txt (line 3)) (3.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from matplotlib->-r ../requirements.txt (line 4)) (3.2.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 6)) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 6)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: bleach in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from kaggle->-r ../requirements.txt (line 8)) (6.2.0)
# Requirement already satisfied: python-slugify in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from kaggle->-r ../requirements.txt (line 8)) (8.0.4)
# Requirement already satisfied: text-unidecode in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from kaggle->-r ../requirements.txt (line 8)) (1.3)
# Requirement already satisfied: tqdm in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from kaggle->-r ../requirements.txt (line 8)) (4.67.1)
# Requirement already satisfied: webencodings in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from kaggle->-r ../requirements.txt (line 8)) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow->-r ../requirements.txt (line 3)) (0.45.1)
# Requirement already satisfied: rich in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from keras>=3.10.0->tensorflow->-r ../requirements.txt (line 3)) (14.1.0)
# Requirement already satisfied: namex in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from keras>=3.10.0->tensorflow->-r ../requirements.txt (line 3)) (0.1.0)
# Requirement already satisfied: optree in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from keras>=3.10.0->tensorflow->-r ../requirements.txt (line 3)) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow->-r ../requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow->-r ../requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow->-r ../requirements.txt (line 3)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow->-r ../requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: colorama in c:\users\owner\onedrive\varsity\2025\pgdda\s2\pdan\projects\poe-part-1\.venv\lib\site-packages (from tqdm->kaggle->-r ../requirements.txt (line 8)) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Dataset loaded successfully!
#         id                                               text author
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL

# %%
# Prepare the data
# Display basic information about the dataset
# Check for missing values
missing_values = data.isnull().sum()
print("Missing values in each column:")
print(missing_values)

# If there are missing values, print a message and fill them
if missing_values.any():
    print("There are missing values in the dataset, using forward fill to handle them.")
    # Preprocess data (fill missing values, encode categorical variables)
    # Fill missing values with forward fill method
    data.fillna(method='ffill', inplace=True)
    print("Missing values after forward fill:")
    print(data.isnull().sum())
# One-hot encode the 'author' column before other encoding
print("Unique authors:", data['author'].unique())
author_dummies = pd.get_dummies(data['author'], prefix='author')
print("One-hot encoded author columns:", author_dummies.columns)
data = pd.concat([data.drop(columns=['author']), author_dummies], axis=1)
print(data.head())
# Out:
# Missing values in each column:
# id        0
# text      0
# author    0
# dtype: int64
# Unique authors: ['EAP' 'HPL' 'MWS']
# One-hot encoded author columns: Index(['author_EAP', 'author_HPL', 'author_MWS'], dtype='object')
#         id                                               text  author_EAP  \
# 0  id26305  This process, however, afforded me no means of...        True
# 1  id17569  It never once occurred to me that the fumbling...       False
# 2  id11008  In his left hand was a gold snuff box, from wh...        True
# 3  id27763  How lovely is spring As we looked from Windsor...       False
# 4  id12958  Finding nothing else, not even gold, the Super...       False
#
#    author_HPL  author_MWS
# 0       False       False
# 1        True       False
# 2       False       False
# 3       False        True
# 4        True       False

# %%
#More imports
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Prepare input and target
X = data['text'].values
y = data[['author_EAP', 'author_HPL', 'author_MWS']].values

# Tokenize and pad text
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X)
X_seq = tokenizer.texts_to_sequences(X)
X_pad = pad_sequences(X_seq, maxlen=200)

# Build the model
model = Sequential([
    Embedding(input_dim=10000, output_dim=64, input_length=200),
    LSTM(64),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_pad, y, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# c:\Users\owner\OneDrive\Varsity\2025\PGDDA\S2\PDAN\Projects\POE-Part-1\.venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - accuracy: 0.6879 - loss: 0.6980 - val_accuracy: 0.8123 - val_loss: 0.4728
# Epoch 2/5
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.8837 - loss: 0.3086 - val_accuracy: 0.8189 - val_loss: 0.4964
# Epoch 3/5
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.9297 - loss: 0.1915 - val_accuracy: 0.8128 - val_loss: 0.5659
# Epoch 4/5
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 21s 44ms/step - accuracy: 0.9518 - loss: 0.1385 - val_accuracy: 0.8054 - val_loss: 0.8051
# Epoch 5/5
# 490/490 ━━━━━━━━━━━━━━━━━━━━ 27s 56ms/step - accuracy: 0.9669 - loss: 0.0966 - val_accuracy: 0.8123 - val_loss: 0.7402

# %%
# Load test data
test_path = "../data/test.csv"
test_data = pd.read_csv(test_path)

print(test_data.head())
# Out:
#         id                                               text
# 0  id02310  Still, as I urged our leaving Ireland with suc...
# 1  id24541  If a fire wanted fanning, it could readily be ...
# 2  id00134  And when they had broken down the frail door t...
# 3  id27757  While I was thinking how I should possibly man...
# 4  id04081  I am not sure to what limit his knowledge may ...

# %%
# Randomly select 10 indices
random_indices = np.random.choice(test_data.index, size=10, replace=False)

for idx in random_indices:
    sample_text = [test_data.loc[idx, 'text']]
    sample_seq = tokenizer.texts_to_sequences(sample_text)
    sample_pad = pad_sequences(sample_seq, maxlen=200)
    pred = model.predict(sample_pad)
    print(f"Text: {sample_text[0][:60]}...")
    print(f"Predicted probabilities (EAP, HPL, MWS): {pred[0]}\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Text: I resolutely and perseveringly kept my attention riveted upo...
# Predicted probabilities (EAP, HPL, MWS): [0.9968522  0.00210096 0.00104676]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Text: Fortunately the village was small and the death rate low, so...
# Predicted probabilities (EAP, HPL, MWS): [0.0015895  0.21289864 0.78551185]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Text: They searched, but found nothing....
# Predicted probabilities (EAP, HPL, MWS): [0.8950657  0.10079294 0.00414137]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Text: The Portuguese sailors coming in from a voyage cross themsel...
# Predicted probabilities (EAP, HPL, MWS): [0.73210263 0.2663502  0.00154712]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Text: The banks of the Thames presented a new scene; they were fla...
# Predicted probabilities (EAP, HPL, MWS): [9.9123463e-05 2.3037689e-04 9.9967051e-01]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Text: The city looked dark to the south, while numerous lights alo...
# Predicted probabilities (EAP, HPL, MWS): [1.2607386e-03 3.0382926e-04 9.9843544e-01]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Text: Why I did so I can hardly tell....
# Predicted probabilities (EAP, HPL, MWS): [0.01659929 0.22053158 0.7628691 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Text: I am full of fears, for if I fail there, I am an outcast in ...
# Predicted probabilities (EAP, HPL, MWS): [1.8973260e-04 5.4406908e-05 9.9975580e-01]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Text: The cat and pigeons seemed to suffer no inconvenience whatso...
# Predicted probabilities (EAP, HPL, MWS): [9.9720180e-01 2.7111084e-03 8.7122840e-05]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Text: The barren old trees in the yard have begun to bear small, s...
# Predicted probabilities (EAP, HPL, MWS): [0.33545512 0.51852983 0.14601502]

# %%
# Example prediction using the random indices to predict authors by name
author_labels = ['EAP', 'HPL', 'MWS']

for idx in random_indices:
    sample_text = [test_data.loc[idx, 'text']]
    sample_seq = tokenizer.texts_to_sequences(sample_text)
    sample_pad = pad_sequences(sample_seq, maxlen=200)
    pred = model.predict(sample_pad)
    pred_idx = np.argmax(pred[0])
    pred_author = author_labels[pred_idx]
    print(f"Text: {sample_text[0][:60]}...")
    print(f"Predicted author: {pred_author}")
    print(f"Probabilities (EAP, HPL, MWS): {pred[0]}\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Text: I resolutely and perseveringly kept my attention riveted upo...
# Predicted author: EAP
# Probabilities (EAP, HPL, MWS): [0.9968522  0.00210096 0.00104676]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Text: Fortunately the village was small and the death rate low, so...
# Predicted author: MWS
# Probabilities (EAP, HPL, MWS): [0.0015895  0.21289864 0.78551185]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Text: They searched, but found nothing....
# Predicted author: EAP
# Probabilities (EAP, HPL, MWS): [0.8950657  0.10079294 0.00414137]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Text: The Portuguese sailors coming in from a voyage cross themsel...
# Predicted author: EAP
# Probabilities (EAP, HPL, MWS): [0.73210263 0.2663502  0.00154712]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Text: The banks of the Thames presented a new scene; they were fla...
# Predicted author: MWS
# Probabilities (EAP, HPL, MWS): [9.9123463e-05 2.3037689e-04 9.9967051e-01]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Text: The city looked dark to the south, while numerous lights alo...
# Predicted author: MWS
# Probabilities (EAP, HPL, MWS): [1.2607386e-03 3.0382926e-04 9.9843544e-01]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Text: Why I did so I can hardly tell....
# Predicted author: MWS
# Probabilities (EAP, HPL, MWS): [0.01659929 0.22053158 0.7628691 ]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Text: I am full of fears, for if I fail there, I am an outcast in ...
# Predicted author: MWS
# Probabilities (EAP, HPL, MWS): [1.8973260e-04 5.4406908e-05 9.9975580e-01]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Text: The cat and pigeons seemed to suffer no inconvenience whatso...
# Predicted author: EAP
# Probabilities (EAP, HPL, MWS): [9.9720180e-01 2.7111084e-03 8.7122840e-05]
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Text: The barren old trees in the yard have begun to bear small, s...
# Predicted author: HPL
# Probabilities (EAP, HPL, MWS): [0.33545512 0.51852983 0.14601502]

# %%
import time
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import skfuzzy as fuzz
from skfuzzy import control as ctrl
from tqdm import tqdm

# Configuration
# Using a smaller number for a quicker run.
NUM_KEYWORDS_PER_AUTHOR = 100
# Authors in the dataset
AUTHORS = ['EAP', 'HPL', 'MWS']

# Helper Functions
# Extract top keywords per author
def extract_top_keywords(train_df, authors, num_keywords):
    """Extracts top TF-IDF keywords for each author."""
    print("✅ Loaded training data with {} rows.".format(len(train_df)))
    
    # Aggregate all text for each author
    author_texts = train_df.groupby('author')['text'].apply(' '.join)
    print(f"✅ Aggregated text for {len(authors)} authors.")
    
    author_keywords = {}
    # Initialize TF-IDF Vectorizer
    vectorizer = TfidfVectorizer(stop_words='english', max_features=num_keywords)
    
    for author in authors:
        # Fit and transform the text for the current author
        vectorizer.fit([author_texts[author]])
        # Get the feature names (keywords)
        keywords = vectorizer.get_feature_names_out()
        author_keywords[author] = keywords
        print(f"📘 {author}: {', '.join(keywords[:5])}...")
        
    return author_keywords
# Build fuzzy logic system
# CoPilot suggestion implementation and improvements using intellisense
def build_fuzzy_system(author_keywords, authors):
    """
    Builds the fuzzy logic control system and rules efficiently.
    This version correctly pre-builds all antecedents before creating rules.
    """
    # Setup Universes and Consequents (Outputs)
    keyword_count_universe = np.arange(0, 11, 1)
    score_universe = np.arange(0, 11, 1)
    
    output_objects = {}
    for author in authors:
        consequent = ctrl.Consequent(score_universe, f'score_{author}')
        consequent['low'] = fuzz.trimf(consequent.universe, [0, 0, 5])
        consequent['medium'] = fuzz.trimf(consequent.universe, [0, 5, 10])
        consequent['high'] = fuzz.trimf(consequent.universe, [5, 10, 10])
        output_objects[author] = consequent

    # Pre-build ALL Antecedents (Inputs)
    # Another change suggested by CoPilot, building all antecedents first and then referencing them
    # This is the critical change: create all input objects first.
    print("    - Defining all input variables (antecedents)...")
    antecedent_objects = {}
    all_author_keyword_pairs = [
        (author, keyword) 
        for author in authors 
        for keyword in author_keywords[author]
    ]
    for author, keyword in all_author_keyword_pairs:
        name = f'{author}_{keyword}_count'
        antecedent = ctrl.Antecedent(keyword_count_universe, name)
        antecedent['low'] = fuzz.trimf(antecedent.universe, [0, 0, 1])
        antecedent['medium'] = fuzz.trimf(antecedent.universe, [0, 2, 4])
        antecedent['high'] = fuzz.smf(antecedent.universe, 3, 5)
        antecedent_objects[name] = antecedent

    # Create Rules by Referencing Existing Objects (with Progress Bar)
    rules = []
    for author, keyword in tqdm(all_author_keyword_pairs, desc="    - Generating rules"):
        # Get the pre-built antecedent and consequent
        antecedent = antecedent_objects[f'{author}_{keyword}_count']
        author_output = output_objects[author]
        
        # Create rules linking them
        rules.append(ctrl.Rule(antecedent['medium'], author_output['medium']))
        rules.append(ctrl.Rule(antecedent['high'], author_output['high']))

    # Finalize the System
    print(f"    - Constructing the control system graph from {len(rules)} rules... (this may take a few minutes)")
    fuzzy_system = ctrl.ControlSystem(rules)
    fuzzy_system_sim = ctrl.ControlSystemSimulation(fuzzy_system)
    
    return fuzzy_system_sim


# --- Main Execution ---
if __name__ == '__main__':
    print("🚀 Starting fuzzy author classification...\n")
    
    # Load the training data
    train_data = pd.read_csv("../data/train.csv")
    train_df = pd.DataFrame(train_data)
    # Load the test data
    test_data = pd.read_csv("../data/test.csv")
    test_df = pd.DataFrame(test_data)

    # Extract top keywords per author
    print("🔍 Step 1: Extracting top keywords per author...")
    start_time = time.time()
    author_keywords = extract_top_keywords(train_df, AUTHORS, NUM_KEYWORDS_PER_AUTHOR)
    print(f"✅ Keyword extraction complete in {time.time() - start_time:.2f} seconds.\n")

    # Build the fuzzy logic system
    print("🧠 Step 2: Building fuzzy logic system...")
    start_time = time.time()
    fuzzy_system_sim = build_fuzzy_system(author_keywords, AUTHORS)
    print(f"✅ Fuzzy system built in {time.time() - start_time:.2f} seconds.\n")

    # Classify test data and evaluate
    print("🧪 Step 3: Classifying test data and evaluating...")
    print(f"✅ Loaded test data with {len(test_df)} rows.")

    # This segment of code has been heavily optimized by CoPilot for speed. I left the original comments for context.
    # ===================================================================
    # START: OPTIMIZED CLASSIFICATION BLOCK
    # ===================================================================
    
    print("\n📊 Pre-calculating keyword counts for the entire test set...")
    # Create a new DataFrame to hold keyword counts for all texts
    keyword_counts_df = pd.DataFrame(index=test_df.index)

    # Use pandas' vectorized string methods for a massive speedup
    all_unique_keywords = set(kw for kws in author_keywords.values() for kw in kws)
    for keyword in tqdm(all_unique_keywords, desc="🔍 Counting keywords"):
        # Count this keyword across all texts at once
        counts = test_df['text'].str.lower().str.count(r'\b' + keyword + r'\b') # Use word boundaries
        # Assign counts to the correct input columns
        for author in AUTHORS:
            if keyword in author_keywords[author]:
                input_name = f'{author}_{keyword}_count'
                keyword_counts_df[input_name] = counts
    
    print("✅ Keyword counts calculated.\n")

    # Classify using the pre-calculated counts
    results = []
    # Build output_names directly from AUTHORS
    output_names = [f'score_{author}' for author in AUTHORS]  # e.g., ['score_EAP', 'score_HPL', 'score_MWS']

    # Convert DataFrame to a list of dicts for faster iteration
    records = keyword_counts_df.to_dict('records')

    for i, record in enumerate(tqdm(records, desc="🔄 Classifying texts")):
        # Pass the pre-calculated counts for one text
        fuzzy_system_sim.inputs(record)
        
        # Compute the fuzzy logic output
        try:
            fuzzy_system_sim.compute()
            # Only include outputs that exist in fuzzy_system_sim.output
            scores = []
            for name in output_names:
                if name in fuzzy_system_sim.output:
                    scores.append(fuzzy_system_sim.output[name])
                else:
                    # If missing, assign a neutral score
                    scores.append(1.67)
        except ValueError:
            # This can happen if no rules are activated. Default to a neutral score.
            scores = [1.67] * len(AUTHORS)

        # --- FIX for tied scores ---
        max_score = np.max(scores)
        
        # Check if all scores are identical and low, indicating no keywords were found
        if all(abs(score - scores[0]) < 0.1 for score in scores) and max_score < 2.0:
            predicted_author = 'UNCLEAR' # Assign a specific label for low-confidence ties
        else:
            # Otherwise, pick the author with the highest score
            predicted_author = AUTHORS[np.argmax(scores)]

        results.append({
            'id': test_df.iloc[i]['id'],
            'predicted': predicted_author,
            'scores': {AUTHORS[j]: round(s, 2) for j, s in enumerate(scores)}
        })

    # ===================================================================
    # END: OPTIMIZED CLASSIFICATION BLOCK
    # ===================================================================

    print("\n✅ Classification complete.\n")
    print("📊 Sample Results:")
    
    # Display the results
    for res in results:
        scores_str = ", ".join([f"{author}={score}" for author, score in res['scores'].items()])
        print(f"ID: {res['id']}, Predicted: {res['predicted']}, Scores: {scores_str}")
# Out:
# 🚀 Starting fuzzy author classification...
#
# 🔍 Step 1: Extracting top keywords per author...
# ✅ Loaded training data with 19579 rows.
# ✅ Aggregated text for 3 authors.
# 📘 EAP: air, altogether, appearance, appeared, attention...
# 📘 HPL: ancient, away, began, black, body...
# 📘 MWS: adrian, affection, air, appeared, away...
# ✅ Keyword extraction complete in 0.21 seconds.
#
# 🧠 Step 2: Building fuzzy logic system...
#     - Defining all input variables (antecedents)...
#     - Generating rules: 100%|██████████| 300/300 [00:00<00:00, 138243.38it/s]
#     - Constructing the control system graph from 600 rules... (this may take a few minutes)
# ✅ Fuzzy system built in 417.36 seconds.
#
# 🧪 Step 3: Classifying test data and evaluating...
# ✅ Loaded test data with 8392 rows.
#
# 📊 Pre-calculating keyword counts for the entire test set...
# 🔍 Counting keywords:  29%|██▉       | 59/201 [00:01<00:02, 47.66it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  32%|███▏      | 64/201 [00:01<00:02, 46.76it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  34%|███▍      | 69/201 [00:01<00:02, 47.09it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  37%|███▋      | 74/201 [00:01<00:02, 47.50it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  39%|███▉      | 79/201 [00:01<00:02, 43.55it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  42%|████▏     | 84/201 [00:01<00:02, 44.96it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  44%|████▍     | 89/201 [00:01<00:02, 45.63it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  47%|████▋     | 94/201 [00:02<00:02, 46.11it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  49%|████▉     | 99/201 [00:02<00:02, 46.52it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  52%|█████▏    | 104/201 [00:02<00:02, 46.98it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  54%|█████▍    | 109/201 [00:02<00:01, 47.46it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  57%|█████▋    | 114/201 [00:02<00:01, 47.73it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  59%|█████▉    | 119/201 [00:02<00:01, 47.67it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  62%|██████▏   | 124/201 [00:02<00:01, 45.70it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  64%|██████▍   | 129/201 [00:02<00:01, 46.39it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  67%|██████▋   | 134/201 [00:02<00:01, 45.45it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# 🔍 Counting keywords:  69%|██████▉   | 139/201 [00:02<00:01, 46.21it/s]C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# C:\Users\owner\AppData\Local\Temp\ipykernel_15776\1923575862.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   keyword_counts_df[input_name] = counts
# ...
# ID: id00504, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=5.0
# ID: id24331, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id03914, Predicted: MWS, Scores: EAP=1.67, HPL=1.67, MWS=5.0
# ID: id16299, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id05565, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id27934, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id17027, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id02785, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id16094, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id22435, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id10586, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id06467, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=1.67
# ID: id18227, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=1.67
# ID: id02286, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id07393, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id11640, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id15718, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id23756, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id14564, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id24963, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id03069, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id24648, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id15920, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id11255, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id00544, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13211, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id26285, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id19879, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id21440, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id09539, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id10781, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id06557, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id16747, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id14358, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id05250, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id02390, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id14790, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id14355, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id23157, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id20324, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id01870, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id01079, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id03392, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id22758, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id05599, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id07189, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id13364, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id00902, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id07164, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id27290, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id18931, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id22165, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id14677, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id18987, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13143, Predicted: HPL, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id18589, Predicted: HPL, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id01635, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id02661, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id12463, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id18461, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id12709, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id11957, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13040, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=5.0
# ID: id03953, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id02623, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id21479, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id06976, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id18721, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id12043, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id16526, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id03184, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id23194, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id17544, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id17314, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id17306, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id11044, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id22762, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id02797, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13340, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id08131, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id24181, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id20359, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=5.0
# ID: id14736, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id09362, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id07987, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=1.67
# ID: id01664, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=1.67
# ID: id00096, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=1.67
# ID: id01475, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id04020, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id09617, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13098, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id19010, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id12754, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id25238, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id14896, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id16827, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id11685, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id10496, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id08073, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id08504, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=5.0
# ID: id25872, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id09498, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id23890, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id15065, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=5.0
# ID: id11197, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id02832, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id26969, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id25442, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id09727, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id18592, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id11442, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id22071, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id09700, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id20265, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id23687, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id01055, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id08519, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id05922, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=1.67
# ID: id02918, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id14502, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id01642, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id21251, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id09673, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id17837, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id24245, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id15837, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13077, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id23079, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id12938, Predicted: MWS, Scores: EAP=1.67, HPL=1.67, MWS=5.0
# ID: id12144, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=5.0
# ID: id06882, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id06354, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=5.0
# ID: id23573, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13800, Predicted: HPL, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id26115, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id21179, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id00125, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id22600, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id15726, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id08078, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id20091, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id00026, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id03698, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id09198, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id12520, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id16277, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id17964, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=5.0
# ID: id24040, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id17613, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id00157, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id10012, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id02419, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id05562, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id09049, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id24915, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=1.67
# ID: id02808, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id00167, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13451, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id24775, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id10240, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id24597, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id15364, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13191, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id09592, Predicted: MWS, Scores: EAP=1.67, HPL=1.67, MWS=5.0
# ID: id12083, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id23492, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id06816, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id16971, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id05675, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id23037, Predicted: MWS, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id00399, Predicted: MWS, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id05925, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id01834, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id20350, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id18961, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id02132, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id26609, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id16532, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id23289, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id26621, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id03254, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id04701, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id26600, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id16006, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id25724, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id27223, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id14345, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id27374, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id21131, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id12410, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id15483, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id15429, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id25480, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=5.0
# ID: id11453, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id20437, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id08468, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id22181, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id18810, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id17482, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id22746, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id03107, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id02184, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id25068, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id19154, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id10358, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id09126, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id05936, Predicted: HPL, Scores: EAP=1.67, HPL=5.0, MWS=5.0
# ID: id00020, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id20771, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id00116, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id12424, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id05755, Predicted: MWS, Scores: EAP=1.67, HPL=1.67, MWS=5.0
# ID: id27476, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id02686, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id10234, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id05969, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id14440, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id09937, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id08238, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id11090, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13183, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id25712, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id22510, Predicted: MWS, Scores: EAP=1.67, HPL=1.67, MWS=5.0
# ID: id19204, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id05758, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id27063, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id11773, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id11562, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id16208, Predicted: MWS, Scores: EAP=1.67, HPL=1.67, MWS=5.0
# ID: id04036, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id26159, Predicted: MWS, Scores: EAP=1.67, HPL=1.67, MWS=5.0
# ID: id26777, Predicted: MWS, Scores: EAP=1.67, HPL=1.67, MWS=5.0
# ID: id08501, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id11216, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id03410, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id04537, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id26628, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id01586, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13421, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id26084, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id05375, Predicted: MWS, Scores: EAP=1.67, HPL=1.67, MWS=5.0
# ID: id23212, Predicted: EAP, Scores: EAP=5.0, HPL=1.67, MWS=5.0
# ID: id15980, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id11719, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id13109, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id07156, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id04893, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id11749, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id10526, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=1.67
# ID: id13477, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id13761, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
# ID: id04282, Predicted: EAP, Scores: EAP=5.0, HPL=5.0, MWS=5.0
